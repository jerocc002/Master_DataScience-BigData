# %%
# Import pandas
% matplotlib inline
import pandas as pd
from pandas.tools.plotting import scatter_matrix

# %% [markdown]
# # Dataset
# https://www.kaggle.com/gregorut/videogamesales
#
# # Description
# This dataset contains a list of video games with sales greater than 100,000 copies. It was generated by a scrape of vgchartz.com.
#
# Fields include
#
# - Rank: Ranking of overall sales
# - Name: The games name
# - Platform: Platform of the games release (i.e. PC,PS4, etc.)
# - Year: Year of the game's release
# - Genre: Genre of the game
# - Publisher: Publisher of the game
# - NA_Sales: Sales in North America (in millions)
# - EU_Sales: Sales in Europe (in millions)
# - JP_Sales: Sales in Japan (in millions)
# - Other_Sales: Sales in the rest of the world (in millions)
# - Global_Sales: Total worldwide sales.

# %%
# Let's take a look to our dataframe
data = pd.read_csv("vgsales.csv")
data
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# 5          6                                             Tetris       GB
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# 8          9                          New Super Mario Bros. Wii      Wii
# 9         10                                          Duck Hunt      NES
# 10        11                                         Nintendogs       DS
# 11        12                                      Mario Kart DS       DS
# ...

# %%
# Let's see the shape of our DataFrame
data.shape
# Out:
# (16598, 11)

# %%
# Now, we see the dtypes of the columns
data.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
# Let's check only the first 5 rows
data.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Let's check the last 5 rows
data.tail(5)
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
# Let's use describe to check the state of the data
data.describe()
# Out:
# /home/usu1/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000           NaN      0.000000      0.000000      0.000000
# 50%     8300.500000           NaN      0.080000      0.020000      0.000000
# 75%    12449.750000           NaN      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# ...

# %%
# If we set the include='all' parameter, we get statistics of the non-numeric column types
data.describe(include='all')
# Out:
# /home/usu1/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                 Rank                         Name Platform          Year  \
# count   16598.000000                        16598    16598  16327.000000
# unique           NaN                        11493       31           NaN
# top              NaN  Need for Speed: Most Wanted       DS           NaN
# freq             NaN                           12     2163           NaN
# mean     8300.605254                          NaN      NaN   2006.406443
# std      4791.853933                          NaN      NaN      5.828981
# min         1.000000                          NaN      NaN   1980.000000
# 25%      4151.250000                          NaN      NaN           NaN
# 50%      8300.500000                          NaN      NaN           NaN
# 75%     12449.750000                          NaN      NaN           NaN
# ...

# %%
# Let's apply some statistical methods to the columns
data['EU_Sales'].mean()
# Out:
# 0.1466520062658483

# %%
# Let's get only the information of the Year 1980
data[data['Year']==1980]
# Out:
#       Rank             Name Platform    Year     Genre   Publisher  NA_Sales  \
# 258    259        Asteroids     2600  1980.0   Shooter       Atari      4.00
# 544    545  Missile Command     2600  1980.0   Shooter       Atari      2.56
# 1766  1768          Kaboom!     2600  1980.0      Misc  Activision      1.07
# 1969  1971         Defender     2600  1980.0      Misc       Atari      0.99
# 2669  2671           Boxing     2600  1980.0  Fighting  Activision      0.72
# 4025  4027       Ice Hockey     2600  1980.0    Sports  Activision      0.46
# 5366  5368          Freeway     2600  1980.0    Action  Activision      0.32
# 6317  6319           Bridge     2600  1980.0      Misc  Activision      0.25
# 6896  6898         Checkers     2600  1980.0      Misc       Atari      0.22
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 258       0.26       0.0         0.05          4.31
# 544       0.17       0.0         0.03          2.76
# ...

# %%
# Let's get only the information of the Game 'Wii Sports'
data[data['Name']=='Wii Sports']
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
# Let's get the games with sales in North America greater than 1.0
NA_data_1 = data[data['NA_Sales']>1.0]

# Extract relevant attributes of the result
platform = NA_data_1['Platform']
genre = NA_data_1['Genre']
publisher=NA_data_1['Publisher']

NA_data_1
# Out:
#       Rank                                          Name Platform    Year  \
# 0        1                                    Wii Sports      Wii  2006.0
# 1        2                             Super Mario Bros.      NES  1985.0
# 2        3                                Mario Kart Wii      Wii  2008.0
# 3        4                             Wii Sports Resort      Wii  2009.0
# 4        5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5        6                                        Tetris       GB  1989.0
# 6        7                         New Super Mario Bros.       DS  2006.0
# 7        8                                      Wii Play      Wii  2006.0
# 8        9                     New Super Mario Bros. Wii      Wii  2009.0
# 9       10                                     Duck Hunt      NES  1984.0
# 10      11                                    Nintendogs       DS  2005.0
# 11      12                                 Mario Kart DS       DS  2005.0
# ...

# %%
# Now, let's calculate the games for each platform
data.groupby(['Platform']).count()
# Out:
#           Rank  Name  Year  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# 2600       133   133   116    133        133       133       133       133
# 3DO          3     3     3      3          3         3         3         3
# 3DS        509   509   500    509        507       509       509       509
# DC          52    52    52     52         52        52        52        52
# DS        2163  2163  2133   2163       2156      2163      2163      2163
# GB          98    98    97     98         98        98        98        98
# GBA        822   822   811    822        796       822       822       822
# GC         556   556   542    556        556       556       556       556
# GEN         27    27    27     27         27        27        27        27
# GG           1     1     1      1          1         1         1         1
# N64        319   319   316    319        319       319       319       319
# ...

# %%
# Now, let's calculate the genre
data.groupby(['Genre']).count()
# Out:
#               Rank  Name  Platform  Year  Publisher  NA_Sales  EU_Sales  \
# Genre
# Action        3316  3316      3316  3253       3309      3316      3316
# Adventure     1286  1286      1286  1276       1282      1286      1286
# Fighting       848   848       848   836        846       848       848
# Misc          1739  1739      1739  1710       1712      1739      1739
# Platform       886   886       886   876        884       886       886
# Puzzle         582   582       582   571        581       582       582
# Racing        1249  1249      1249  1226       1248      1249      1249
# Role-Playing  1488  1488      1488  1471       1486      1488      1488
# Shooter       1310  1310      1310  1282       1308      1310      1310
# Simulation     867   867       867   851        863       867       867
# Sports        2346  2346      2346  2304       2343      2346      2346
# Strategy       681   681       681   671        678       681       681
#
# ...

# %%
# Now, let's calculate the publisher
data.groupby(['Publisher']).count()
# Out:
#                                         Rank  Name  Platform  Year  Genre  \
# Publisher
# 10TACLE Studios                            3     3         3     3      3
# 1C Company                                 3     3         3     3      3
# 20th Century Fox Video Games               5     5         5     5      5
# 2D Boy                                     1     1         1     1      1
# 3DO                                       36    36        36    36     36
# 49Games                                    1     1         1     1      1
# 505 Games                                192   192       192   192    192
# 5pb                                       61    61        61    61     61
# 7G//AMES                                   4     4         4     4      4
# 989 Sports                                 1     1         1     1      1
# 989 Studios                               14    14        14    14     14
# ...

# %%
##################
# Visualization
##################

# %%
# Histogram
data.hist(figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fba758f3e48>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fba7566ce10>]], dtype=object)

# %%
# Plot the global sales per year
data.groupby('Year').sum()['Global_Sales'].plot()

# %%
# Scatter matrix over all the data in the data frame
scatter_matrix(data, alpha=0.2, figsize=(30,20), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fba75360a90>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fba6e835f98>]], dtype=object)

# %%
# Scatter matrix over Global_Sales and NA_Sales
scatter_matrix(data[['Global_Sales','NA_Sales']], alpha=0.2, figsize=(30,20), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c9abf1d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c98bfeb8>]], dtype=object)
