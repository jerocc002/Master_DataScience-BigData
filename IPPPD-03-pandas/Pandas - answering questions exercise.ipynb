# %%
# Import pandas
% matplotlib inline
import pandas as pd
from pandas.tools.plotting import scatter_matrix

# %% [markdown]
# # Dataset
# https://www.kaggle.com/gregorut/videogamesales
#
# # Description
# This dataset contains a list of video games with sales greater than 100,000 copies. It was generated by a scrape of vgchartz.com.
#
# Fields include
#
# - Rank: Ranking of overall sales
# - Name: The games name
# - Platform: Platform of the games release (i.e. PC,PS4, etc.)
# - Year: Year of the game's release
# - Genre: Genre of the game
# - Publisher: Publisher of the game
# - NA_Sales: Sales in North America (in millions)
# - EU_Sales: Sales in Europe (in millions)
# - JP_Sales: Sales in Japan (in millions)
# - Other_Sales: Sales in the rest of the world (in millions)
# - Global_Sales: Total worldwide sales.

# %%
# Load the data into a dataframe
df = pd.read_csv("vgsales.csv")

# %% [markdown]
# Platforms presented in the dataset

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16', '3DO',
#        'GG', 'PCFX'], dtype=object)

# %% [markdown]
# Sales for them

# %%
df.groupby('Platform').sum()['Global_Sales']
# Out:
# Platform
# 2600      97.08
# 3DO        0.10
# 3DS      247.46
# DC        15.97
# DS       822.49
# GB       255.45
# GBA      318.50
# GC       199.36
# GEN       28.36
# GG         0.04
# N64      218.88
# NES      251.07
# NG         1.44
# PC       258.82
# PCFX       0.03
# PS       730.66
# PS2     1255.64
# PS3      957.84
# PS4      278.10
# PSP      296.28
# PSV       61.93
# SAT       33.59
# SCD        1.87
# SNES     200.05
# TG16       0.16
# WS         1.42
# Wii      926.71
# WiiU      81.86
# X360     979.96
# XB       258.26
# XOne     141.06
# Name: Global_Sales, dtype: float64

# %% [markdown]
# Genres presented in the dataset and sales for them

# %%
df['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
df.groupby('Genre').sum()['Global_Sales']
# Out:
# Genre
# Action          1751.18
# Adventure        239.04
# Fighting         448.91
# Misc             809.96
# Platform         831.37
# Puzzle           244.95
# Racing           732.04
# Role-Playing     927.37
# Shooter         1037.37
# Simulation       392.20
# Sports          1330.93
# Strategy         175.12
# Name: Global_Sales, dtype: float64

# %% [markdown]
# Top 20 biggest publishers in the dataset

# %%
df.groupby('Publisher').sum()['Global_Sales'].sort_values(ascending=False).head(20)
# Out:
# Publisher
# Nintendo                                  1786.56
# Electronic Arts                           1110.32
# Activision                                 727.46
# Sony Computer Entertainment                607.50
# Ubisoft                                    474.72
# Take-Two Interactive                       399.54
# THQ                                        340.77
# Konami Digital Entertainment               283.64
# Sega                                       272.99
# Namco Bandai Games                         254.09
# Microsoft Game Studios                     245.79
# Capcom                                     200.89
# Atari                                      157.22
# Warner Bros. Interactive Entertainment     153.89
# Square Enix                                145.18
# Disney Interactive Studios                 119.96
# Eidos Interactive                           98.98
# LucasArts                                   87.34
# Bethesda Softworks                          82.14
# Midway Games                                69.85
# Name: Global_Sales, dtype: float64

# %% [markdown]
# Games released per year

# %%
df.groupby(['Year','Name']).size()
# Out:
# Year    Name
# 1980.0  Asteroids                                           1
#         Boxing                                              1
#         Bridge                                              1
#         Checkers                                            1
#         Defender                                            1
#         Freeway                                             1
#         Ice Hockey                                          1
#         Kaboom!                                             1
#         Missile Command                                     1
# 1981.0  Adventures of Tron                                  1
#         Air Raid                                            1
#         Airlock                                             1
#         Alien                                               1
#         Armor Ambush                                        1
#         Astroblast                                          1
#         Atlantis                                            1
#         Barnstorming                                        1
#         Berzerk                                             1
#         BurgerTime                                          1
#         Carnival                                            1
#         Centipede                                           1
#         Cosmic Ark                                          1
#         Crazy Climber                                       1
#         Custer's Revenge                                    1
#         Dark Cavern                                         1
#         Deadly Duck                                         1
#         Demon Attack                                        1
#         Donkey Kong                                         1
#         Donkey Kong Junior                                  1
#         Dragonfire                                          1
#                                                            ..
# 2016.0  This War of Mine                                    1
#         Tokyo Xanadu eX+                                    1
#         Tom Clancy's The Division                           3
#         Total War Attila: Tyrants & Kings                   1
#         Total War: WARHAMMER                                1
#         Touhou Genso Rondo: Bullet Ballet                   1
#         Toukiden 2                                          3
#         TrackMania Turbo                                    3
#         UEFA Euro 2016                                      2
#         Uncharted 4: A Thief's End                          1
#         Uppers                                              1
#         Uta no Prince-Sama: Music 3                         1
#         Utawarerumono: Futari no Hakuoro                    3
#         Valentino Rossi: The Game                           3
#         Valkyria Chronicles                                 1
#         Wand of Fortune R                                   1
#         Winning Post 8 2016                                 1
#         World of Warcraft: Legion                           1
#         Worms: WMD                                          1
#         XCOM 2                                              3
#         Yakuza Kiwami                                       2
#         Yokai Sangokushi                                    1
#         Yokai Watch 3                                       1
#         Ys VIII: Lacrimosa of Dana                          1
#         Yuusha Shisu.                                       1
#         Zero Escape: Zero Time Dilemma                      2
#         ZombiU                                              1
# 2017.0  Brothers Conflict: Precious Baby                    1
#         Phantasy Star Online 2 Episode 4: Deluxe Package    2
# 2020.0  Imagine: Makeup Artist                              1
# dtype: int64

# %%
df2 = pd.DataFrame({'NumRel': df.groupby(['Year','Name']).size()}).reset_index()
df2.groupby('Year').sum()['NumRel']
# Out:
# Year
# 1980.0       9
# 1981.0      46
# 1982.0      36
# 1983.0      17
# 1984.0      14
# 1985.0      14
# 1986.0      21
# 1987.0      16
# 1988.0      15
# 1989.0      17
# 1990.0      16
# 1991.0      41
# 1992.0      43
# 1993.0      60
# 1994.0     121
# 1995.0     219
# 1996.0     263
# 1997.0     289
# 1998.0     379
# 1999.0     338
# 2000.0     349
# 2001.0     482
# 2002.0     829
# 2003.0     775
# 2004.0     763
# 2005.0     941
# 2006.0    1008
# 2007.0    1202
# 2008.0    1428
# 2009.0    1431
# 2010.0    1259
# 2011.0    1139
# 2012.0     657
# 2013.0     546
# 2014.0     582
# 2015.0     614
# 2016.0     344
# 2017.0       3
# 2020.0       1
# Name: NumRel, dtype: int64

# %% [markdown]
# Sales per platform between 2007-2011

# %%
df[(df['Year']>=2007) & (df['Year']<=2011)].groupby(['Year','Platform']).sum()['Global_Sales']
# Out:
# Year    Platform
# 2007.0  DC            0.02
#         DS          149.36
#         GBA           3.43
#         GC            0.27
#         PC            9.40
#         PS2          76.00
#         PS3          73.81
#         PSP          47.48
#         Wii         154.97
#         X360         95.84
#         XB            0.55
# 2008.0  DC            0.04
#         DS          147.89
#         PC           12.67
#         PS2          53.83
#         PS3         119.69
#         PSP          34.68
#         Wii         174.16
#         X360        135.76
#         XB            0.18
# 2009.0  DS          121.99
#         PC           17.16
#         PS2          26.45
#         PS3         132.34
#         PSP          38.07
#         Wii         210.44
#         X360        120.85
# 2010.0  DS           87.98
#         PC           24.46
#         PS2           5.63
#         PS3         144.42
#         PSP          35.11
#         Wii         131.80
#         X360        171.05
# 2011.0  3DS          62.53
#         DS           27.80
#         PC           35.25
#         PS2           0.47
#         PS3         159.37
#         PSP          17.89
#         PSV           5.15
#         Wii          62.41
#         X360        145.12
# Name: Global_Sales, dtype: float64

# %% [markdown]
# Sales per genre between 2007-2011

# %%
df[(df['Year']>=2007) & (df['Year']<=2011)].groupby(['Year','Genre']).sum()['Global_Sales']
# Out:
# Year    Genre
# 2007.0  Action          106.50
#         Adventure        24.47
#         Fighting         17.61
#         Misc             92.27
#         Platform         35.59
#         Puzzle           24.00
#         Racing           39.17
#         Role-Playing     43.89
#         Shooter          71.04
#         Simulation       48.97
#         Sports           98.20
#         Strategy          9.42
# 2008.0  Action          136.39
#         Adventure        25.02
#         Fighting         35.38
#         Misc             87.03
#         Platform         35.70
#         Puzzle           15.59
#         Racing           70.66
#         Role-Playing     59.83
#         Shooter          59.51
#         Simulation       46.76
#         Sports           95.34
#         Strategy         11.69
# 2009.0  Action          139.36
#         Adventure        20.68
#         Fighting         32.15
#         Misc             76.94
#         Platform         41.09
#         Puzzle           20.31
#         Racing           34.19
#         Role-Playing     47.90
#         Shooter          69.89
#         Simulation       33.71
#         Sports          138.52
#         Strategy         12.56
# 2010.0  Action          117.64
#         Adventure        16.57
#         Fighting         14.89
#         Misc             96.86
#         Platform         31.90
#         Puzzle           11.18
#         Racing           34.93
#         Role-Playing     70.52
#         Shooter          77.41
#         Simulation       22.15
#         Sports           92.53
#         Strategy         13.87
# 2011.0  Action          118.96
#         Adventure        15.98
#         Fighting         22.68
#         Misc             56.08
#         Platform         28.11
#         Puzzle            5.11
#         Racing           35.01
#         Role-Playing     53.37
#         Shooter          99.36
#         Simulation       15.28
#         Sports           56.99
#         Strategy          9.06
# Name: Global_Sales, dtype: float64

# %% [markdown]
# Most popular games in various genres

# %%
# Cierta ambigüedad; dos soluciones:
# 1) Juego más popular en cada género
dfMaxByGenre = pd.DataFrame({'Global_Sales': df.groupby(['Genre']).max()['Global_Sales']}).reset_index()
df.merge(dfMaxByGenre,on=['Genre','Global_Sales'])
# Out:
#     Rank                                Name Platform    Year         Genre  \
# 0      1                          Wii Sports      Wii  2006.0        Sports
# 1      2                   Super Mario Bros.      NES  1985.0      Platform
# 2      3                      Mario Kart Wii      Wii  2008.0        Racing
# 3      5            Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# 4      6                              Tetris       GB  1989.0        Puzzle
# 5      8                            Wii Play      Wii  2006.0          Misc
# 6     10                           Duck Hunt      NES  1984.0       Shooter
# 7     11                          Nintendogs       DS  2005.0    Simulation
# 8     17                  Grand Theft Auto V      PS3  2013.0        Action
# 9     40             Super Smash Bros. Brawl      Wii  2008.0      Fighting
# 10    51  Super Mario Land 2: 6 Golden Coins       GB  1992.0     Adventure
# 11   166                     Pokemon Stadium      N64  1999.0      Strategy
#
#                Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0               Nintendo     41.49     29.02      3.77         8.46
# 1               Nintendo     29.08      3.58      6.81         0.77
# 2               Nintendo     15.85     12.88      3.79         3.31
# 3               Nintendo     11.27      8.89     10.22         1.00
# 4               Nintendo     23.20      2.26      4.22         0.58
# 5               Nintendo     14.03      9.20      2.93         2.85
# 6               Nintendo     26.93      0.63      0.28         0.47
# 7               Nintendo      9.07     11.00      1.93         2.75
# 8   Take-Two Interactive      7.01      9.27      0.97         4.14
# 9               Nintendo      6.75      2.61      2.66         1.02
# 10              Nintendo      6.16      2.04      2.69         0.29
# 11              Nintendo      3.18      1.24      0.94         0.09
#
#     Global_Sales
# 0          82.74
# 1          40.24
# 2          35.82
# 3          31.37
# 4          30.26
# 5          29.02
# 6          28.31
# 7          24.76
# 8          21.40
# 9          13.04
# 10         11.18
# 11          5.45

# %%
# 2) Juegos más populares en varios géneros (=> juegos calificados en más de un género)
df3 = pd.DataFrame({'SumGSales': df.groupby(['Name','Genre']).sum()['Global_Sales']}).reset_index()
df4 = pd.DataFrame({'NGenres': df3.groupby(['Name']).count()['Genre'].sort_values(ascending=False)}).reset_index()
df5 = df4[(df4['NGenres']>1)]
df.merge(df5,on='Name').sort_values(['Name','Genre','Global_Sales'])
# Out:
#      Rank                                  Name Platform    Year      Genre  \
# 3    8680                              Culdcept      3DS  2012.0       Misc
# 4   14556                              Culdcept      PS2  2002.0   Strategy
# 10  14860     Little Busters! Converted Edition      PSV  2012.0     Action
# 9   13668     Little Busters! Converted Edition      PSP  2010.0  Adventure
# 8   13047     Little Busters! Converted Edition      PS2  2009.0  Adventure
# 6   12627  Steins;Gate: Hiyoku Renri no Darling      PSP  2012.0     Action
# 7   15460  Steins;Gate: Hiyoku Renri no Darling      PS3  2012.0  Adventure
# 5   11439  Steins;Gate: Hiyoku Renri no Darling     X360  2011.0  Adventure
# 1    8841                             Syndicate      PS3  2012.0    Shooter
# 0    8002                             Syndicate     X360  2012.0    Shooter
# 2   12528                             Syndicate       PC  1992.0   Strategy
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 3          Nintendo      0.00      0.00      0.16         0.00          0.16
# 4              Sega      0.01      0.01      0.00         0.00          0.03
# 10        Prototype      0.00      0.00      0.03         0.00          0.03
# 9         Prototype      0.00      0.00      0.04         0.00          0.04
# 8         Prototype      0.00      0.00      0.05         0.00          0.05
# 6               5pb      0.00      0.00      0.06         0.00          0.06
# 7               5pb      0.00      0.00      0.02         0.00          0.02
# 5               5pb      0.00      0.00      0.08         0.00          0.08
# 1          EA Games      0.07      0.06      0.00         0.02          0.15
# 0   Electronic Arts      0.10      0.06      0.00         0.02          0.18
# 2   Electronic Arts      0.00      0.05      0.00         0.01          0.06
#
#     NGenres
# 3         2
# 4         2
# 10        2
# 9         2
# 8         2
# 6         2
# 7         2
# 5         2
# 1         2
# 0         2
# 2         2

# %% [markdown]
# Most popular games per year

# %%
dfMaxByYear = pd.DataFrame({'Global_Sales': df.groupby(['Year']).max()['Global_Sales']}).reset_index()
df.merge(dfMaxByYear,on=['Year','Global_Sales']).sort_values('Year')
# Out:
#      Rank                                              Name Platform    Year  \
# 35    259                                         Asteroids     2600  1980.0
# 33    240                                          Pitfall!     2600  1981.0
# 26     90                                           Pac-Man     2600  1982.0
# 36    422                                          Baseball      NES  1983.0
# 6      10                                         Duck Hunt      NES  1984.0
# 1       2                                 Super Mario Bros.      NES  1985.0
# 28    128                               The Legend of Zelda      NES  1986.0
# 34    252                   Zelda II: The Adventure of Link      NES  1987.0
# 14     23                               Super Mario Bros. 3      NES  1988.0
# 5       6                                            Tetris       GB  1989.0
# 13     19                                 Super Mario World     SNES  1990.0
# 32    232           The Legend of Zelda: A Link to the Past     SNES  1991.0
# 22     51                Super Mario Land 2: 6 Golden Coins       GB  1992.0
# 24     58                             Super Mario All-Stars     SNES  1993.0
# 25     72                               Donkey Kong Country     SNES  1994.0
# 30    188         Donkey Kong Country 2: Diddy's Kong Quest     SNES  1995.0
# 4       5                          Pokemon Red/Pokemon Blue       GB  1996.0
# 23     53                                      Gran Turismo       PS  1997.0
# 18     31           Pokémon Yellow: Special Pikachu Edition       GB  1998.0
# 8      13                       Pokemon Gold/Pokemon Silver       GB  1999.0
# 29    133                           Pokémon Crystal Version       GB  2000.0
# 16     29                            Gran Turismo 3: A-Spec      PS2  2001.0
# 15     25                       Grand Theft Auto: Vice City      PS2  2002.0
# 27    105                        Need for Speed Underground      PS2  2003.0
# 12     18                     Grand Theft Auto: San Andreas      PS2  2004.0
# 7      11                                        Nintendogs       DS  2005.0
# 0       1                                        Wii Sports      Wii  2006.0
# 9      14                                           Wii Fit      Wii  2007.0
# 2       3                                    Mario Kart Wii      Wii  2008.0
# 3       4                                 Wii Sports Resort      Wii  2009.0
# 10     16                                Kinect Adventures!     X360  2010.0
# 17     30                    Call of Duty: Modern Warfare 3     X360  2011.0
# 20     35                        Call of Duty: Black Ops II      PS3  2012.0
# 11     17                                Grand Theft Auto V      PS3  2013.0
# 21     45                                Grand Theft Auto V      PS4  2014.0
# 19     34                         Call of Duty: Black Ops 3      PS4  2015.0
# 31    222                                           FIFA 17      PS4  2016.0
# 38  14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4  2017.0
# 37   5959                            Imagine: Makeup Artist       DS  2020.0
#
#            Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 35       Shooter                        Atari      4.00      0.26      0.00
# 33      Platform                   Activision      4.21      0.24      0.00
# 26        Puzzle                        Atari      7.28      0.45      0.00
# 36        Sports                     Nintendo      0.73      0.10      2.35
# 6        Shooter                     Nintendo     26.93      0.63      0.28
# 1       Platform                     Nintendo     29.08      3.58      6.81
# 28        Action                     Nintendo      3.74      0.93      1.69
# 34     Adventure                     Nintendo      2.19      0.50      1.61
# 14      Platform                     Nintendo      9.54      3.44      3.84
# 5         Puzzle                     Nintendo     23.20      2.26      4.22
# 13      Platform                     Nintendo     12.78      3.75      3.54
# 32        Action                     Nintendo      2.42      0.91      1.15
# 22     Adventure                     Nintendo      6.16      2.04      2.69
# 24      Platform                     Nintendo      5.99      2.15      2.12
# 25      Platform                     Nintendo      4.36      1.71      3.00
# 30      Platform                     Nintendo      2.10      0.74      2.20
# 4   Role-Playing                     Nintendo     11.27      8.89     10.22
# 23        Racing  Sony Computer Entertainment      4.02      3.87      2.54
# 18  Role-Playing                     Nintendo      5.89      5.04      3.12
# 8   Role-Playing                     Nintendo      9.00      6.18      7.20
# 29  Role-Playing                     Nintendo      2.55      1.56      1.29
# 16        Racing  Sony Computer Entertainment      6.85      5.09      1.87
# 15        Action         Take-Two Interactive      8.41      5.49      0.47
# 27        Racing              Electronic Arts      3.27      2.83      0.08
# 12        Action         Take-Two Interactive      9.43      0.40      0.41
# 7     Simulation                     Nintendo      9.07     11.00      1.93
# 0         Sports                     Nintendo     41.49     29.02      3.77
# 9         Sports                     Nintendo      8.94      8.03      3.60
# 2         Racing                     Nintendo     15.85     12.88      3.79
# 3         Sports                     Nintendo     15.75     11.01      3.28
# 10          Misc       Microsoft Game Studios     14.97      4.94      0.24
# 17       Shooter                   Activision      9.03      4.28      0.13
# 20       Shooter                   Activision      4.99      5.88      0.65
# 11        Action         Take-Two Interactive      7.01      9.27      0.97
# 21        Action         Take-Two Interactive      3.80      5.81      0.36
# 19       Shooter                   Activision      5.77      5.81      0.35
# 31        Sports              Electronic Arts      0.28      3.75      0.06
# 38  Role-Playing                         Sega      0.00      0.00      0.03
# 37    Simulation                      Ubisoft      0.27      0.00      0.00
#
#     Other_Sales  Global_Sales
# 35         0.05          4.31
# 33         0.05          4.50
# 26         0.08          7.81
# 36         0.02          3.20
# 6          0.47         28.31
# 1          0.77         40.24
# 28         0.14          6.51
# 34         0.08          4.38
# 14         0.46         17.28
# 5          0.58         30.26
# 13         0.55         20.61
# 32         0.13          4.61
# 22         0.29         11.18
# 24         0.29         10.55
# 25         0.23          9.30
# 30         0.11          5.15
# 4          1.00         31.37
# 23         0.52         10.95
# 18         0.59         14.64
# 8          0.71         23.10
# 29         0.99          6.39
# 16         1.16         14.98
# 15         1.78         16.15
# 27         1.02          7.20
# 12        10.57         20.81
# 7          2.75         24.76
# 0          8.46         82.74
# 9          2.15         22.72
# 2          3.31         35.82
# 3          2.96         33.00
# 10         1.67         21.82
# 17         1.32         14.76
# 20         2.52         14.03
# 11         4.14         21.40
# 21         2.02         11.98
# 19         2.31         14.24
# 31         0.69          4.77
# 38         0.00          0.03
# 37         0.02          0.29
